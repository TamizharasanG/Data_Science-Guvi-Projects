# %% [markdown]
# <a href="https://colab.research.google.com/github/TamizharasanG/Guvi_Tasks/blob/main/Phonebook_assignment_MongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Phonebook:
    def __init__(self, name, number, email_id):
        self.name = name
        self.number = number
        self.email_id = email_id
    def register(self):
        a = 0#count increases when a invalid name entered
        b = 0#count increases when a invalid number entered
        c = 0#count increases when the invalid mail id entered
        Name = (self.name).replace(" ", "")
        if (Name).isalpha():
            print("Name vaild")
            a +=0
        else:
            print("Name invalid...!Please enter a valid name!!!")
            a+=1
        if len(self.number) == 10 and (self.number).isdigit():
            print("Number validated!")
            b+=0
        elif len(self.number) != 10 or not((self.number).isdigit()):
            print("Number invalid...!Please enter a valid number...!")
            b+=1
        user_name = self.email_id
        x = user_name.split("@")
        if user_name.endswith("@gmail.com") or user_name.endswith("@yahoo.in") or user_name.endswith("@hotmail.com") or user_name.endswith("@reddifmail.com"):
            c+=0
            if user_name[0].isalpha():
                c+=0
                for i in x[0]:
                    if i.isdigit():
                        continue
                    if i.isalpha():
                        continue 
                    elif i == "_" or i == ".":
                        continue
                    else:
                        c+=1               
            else:
                c+=1
        else:
            c+=1
        if c>0:
            print("Your mail_id is invalid")
        elif c == 0:
            print("Email id is validated")
        if a==0 and b==0 and c==0: 
            info = {"name":(self.name).capitalize(), "number":self.number, "email id":self.email_id}
            import pymongo
            client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
            db = client.pb
            records = db.phonebook
            import pandas as pd
            m = records.find()
            t = pd.DataFrame(m)
            n = t.iloc[:,2]
            c_info = []
            for i in n:
                c_info.append(i)
            #used to avoid the duplicate entry
            if self.number in c_info:
                print("Number already enroled..!")
            elif self.number not in c_info:
                records.insert_one(info)
                #print(c_info)
                #print(info)
                print("Details updated")
        elif a !=0 or b !=0 or c !=0:
            print("Details entered are invalid please enter valid details")

# %%
class Find_contacts:
    #for finding contach by name or number, delect contact, and show contacts
    def by_name():
        Name = (input("Enter name : ")).capitalize()
        import pymongo
        client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
        db = client.pb
        records = db.phonebook
        info = records.find({"name": Name}, {"_id":0})
        inf = []
        for i in info:
            inf.append(i)
        if len(inf) == 0:
            print("Contact doesnot exist.")
        elif len(inf) >0:
            for i in inf:
                print(i)
    def by_number():
        Number = input("Enter number : ")
        import pymongo
        client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
        db = client.pb
        records = db.phonebook
        info = records.find({"number":Number}, {"_id":0})
        inf = []
        for i in info:
            inf.append(i)
        if len(inf) == 0:
            print("Contact doesnot exist.")
        elif len(inf) >0:
            for i in inf:
                print(i)
    def delete_contact():
        Name = (input("Enter name : ")).capitalize()
        import pymongo
        client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
        db = client.pb
        records = db.phonebook
        info = records.find({"name":Name})
        inf = []
        for i in info:
            inf.append(i)
        if len(inf) == 0:
            print("Contact doesnot exist!")
        elif len(inf) > 0:
            records.delete_one({"name":Name})
            print("Contact deleted successfully!")
            
    def display_contacts():
        import pymongo
        client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
        db = client.pb
        records = db.phonebook
        info = records.find({},{"_id":0})
        import pandas as pd
        disp = pd.DataFrame(info)
        display(disp)

# %%
class Edit_contact():
    #"a" is a counter, it will remain 0 if no such contact available
    def edit_name():
        a = 0 
        Number = input("Enter your number : ")
        new_name = input("Enter your new name : ").capitalize()
        Name = new_name.replace(" " , "")
        if (Name).isalpha():
            print("Name vaild")
            a +=0
            import pymongo
            client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
            db = client.pb
            records = db.phonebook
            import pandas as pd
            m = records.find()
            t = pd.DataFrame(m)
            n = t.iloc[:,2]
            c_info = []
            for i in n:
                if i == Number:
                    a +=1
                elif i != Number:
                    a+=0
                #used to avoid the duplicate entry
            if a >0:
                myquery = {"number":Number} 
                update = {"$set" :{"name":new_name}}
                records.update_one(myquery, update)
                print("Name updated successfully")
            elif a == 0:
                print("No such contact exist...!")
        else:
          print("Name invalid...!Please enter a valid name!!!")
          a+=1
    def edit_number():
        a = 0
        Number = input("Enter your number : ")
        new_number = input("Enter your new number : ")
        if (new_number).isdigit() and len(new_number) == 10:
            import pymongo
            client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
            db = client.pb
            records = db.phonebook
            import pandas as pd
            m = records.find()
            t = pd.DataFrame(m)
            n = t.iloc[:,2]
            c_info = []
            for i in n:  
              if i == Number:      
                  a +=0  
              elif i != Number:      
                  a+=1  
              #used to avoid the duplicate entry
            if a == 0:  
              myquery = {"number":Number}  
              update = {"$set" :{"number":new_number}}
              records.update_one(myquery, update)
              print("Number updated successfully")
            elif a > 0:
              print("No such contact exist...!")
        else:
          print("Enter a valid number...!!!")
  

    def edit_mailId():
        a = 0
        Number = input("Enter your number : ")
        new_mailId = input("Enter your new mail id : ")
        import pymongo
        client = pymongo.MongoClient("mongodb+srv://TAMIZH:8098437489@cluster0.1x0yt9p.mongodb.net/?retryWrites=true&w=majority")
        db = client.pb
        records = db.phonebook
        import pandas as pd
        m = records.find()
        t = pd.DataFrame(m)
        n = t.iloc[:,2]
        c_info = []
        for i in n:
            if i == Number:
                a +=1
            elif i != Number:
                a+=0
            #used to avoid the duplicate entry
        if a >0:
            myquery = {"number":Number} 
            update = {"$set" :{"email id":new_mailId}}
            records.update_one(myquery, update)
            print("Email id updated successfully.")
        elif a == 0:
            print("No such contact exist...!")

# %%
def phonebook():
    inp = input("For createing contact enter A ; For searching for contact enter B ; For delete contact enter D ; For edit contact enter E :").upper()
    if inp == "A":
        a = Phonebook(input("Enter your name :"), input("Enter your number : "), input("Enter your email id"))
        a.register()
    elif inp == "B":
        b = Find_contacts
        m = input("To search by name enter N ; To search by number enter M ;To display all contacts enter C :").upper()
        if m == "N":
            b.by_name()
        elif m == "M":
            b.by_number()
        elif m == "C":
            b.display_contacts()
        elif m !="N" or m !="M" or m != "C":
            print("Please enter the valid key.")
    elif inp == "D":
        b = Find_contacts
        b.delete_contact()
    elif inp == "E":
        c = Edit_contact
        n = input("To edit name enter N ; To edit number enter M ; To edit mail id enter P : ").upper()
        if n == "N":
            c.edit_name()
        elif n == "M":
            c.edit_number()
        elif n == "P":
            c.edit_mailId()
        elif n !="N" or n !="M" or n != "P":
            print("Please enter the valid key.")
    elif inp != "A" or inp !="B" or inp !="D" or inp != "E":
        print("Please enter the valid key...!")

# %%
phonebook()
# Out:
# For createing contact enter A ; For searching for contact enter B ; For delete contact enter D ; For edit contact enter E :d
# Enter name : 9080437488
# Contact deleted successfully!
